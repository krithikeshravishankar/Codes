# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dt = 0.001
n = 10000

time = np.arange(n)*dt

x = np.zeros(n)
x[0] = 5

for t in np.arange(n - 1):
    x[t + 1] = np.tanh(1 + x[t])

plt.figure()
plt.plot(time, x)
