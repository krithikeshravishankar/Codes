# %%
import numpy as np
import scipy.sparse as sp
import matplotlib.pyplot as plt
from numpy.linalg import norm
from mpl_toolkits.mplot3d import Axes3D

# %%
## Sprott-Linz system parameters 
a = 0.402

## Simulation parameters
T = 100
dt = 0.002
ntraining = int(T / dt)
trainingtimes = np.linspace(0, T, ntraining + 1)

x0 = 1.0 * np.random.rand() - 0.5
y0 = 1.0 * np.random.rand() - 0.5
z0 = 1.0 * np.random.rand() - 0.5
x, y, z = x0, y0, z0
f = np.zeros((3, ntraining))

for t in range(ntraining):

    u = np.array([x, y, z])
    
    xp = y + z 
    yp = -x + a * y 
    zp = x**2 - z

    x += dt * xp
    y += dt * yp
    z += dt * zp

    f[:, t] = u

plt.figure()
ax = plt.axes(projection = '3d')
ax.plot3D(f[0], f[1], f[2], 'r', linewidth = 0.5, label = 'True model')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

print(f[:, -1])
# Out:
# [-1.77609163 -1.46714283  2.74117817]
